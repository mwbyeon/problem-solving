# %%
# Turn 1
# 6000이하, 1200이상 클릭이 있을 경우 alpha 0.98 

# %matplotlib inline
import matplotlib.pyplot as plt
max_impression = {1: 2000, 2: 2000, 3: 2000, 4: 2000, 5: 2000, 6: 2000, 7: 2000, 8: 2000, 9: 2000, 10: 2000, 11: 5000, 12: 5000, 13: 5000, 14: 5000, 15: 5000, 16: 5000, 17: 5000, 18: 5000, 19: 5000, 20: 5000, 21: 10000, 22: 10000, 23: 10000, 24: 10000, 25: 10000, 26: 10000, 27: 10000, 28: 10000, 29: 10000, 30: 10000, 31: 20000, 32: 20000, 33: 20000, 34: 20000, 35: 20000, 36: 20000, 37: 20000, 38: 20000, 39: 20000, 40: 20000}

x_axis = []
y_axis = [ [] for _ in xrange(40) ]
y_score = []
y_clicks = []
for line in open('media_count_v2_8', 'r'):
    line = line.strip().split()
    if line :
        x_axis.append(int(line[0]))
        y_score.append((int(line[1])))
        y_clicks.append((int(line[2])))
        for y in xrange(40):
            y_axis[y].append(float(line[y+4])/max_impression[y+1])

fig, ax1 = plt.subplots(figsize=(20,10))
for i in xrange(40):
    ax1.grid(True)
    ax1.plot(x_axis, y_axis[i], '.')

ax2 = ax1.twinx()
ax2.plot(x_axis, y_score, 'r.')

ax3 = ax1.twinx()
ax3.plot(x_axis, y_clicks, 'yo')
ax3.set_title('score = 2,606,140,682  ')

#plt.hist(y_axis, 100)

# %%
# get_paid_ad() total_impression 버그 수정
# 내가 원하던 그래프가 아니야.

# %matplotlib inline
import matplotlib.pyplot as plt

max_impression = {1: 2000, 2: 2000, 3: 2000, 4: 2000, 5: 2000, 6: 2000, 7: 2000, 8: 2000, 9: 2000, 10: 2000, 11: 5000, 12: 5000, 13: 5000, 14: 5000, 15: 5000, 16: 5000, 17: 5000, 18: 5000, 19: 5000, 20: 5000, 21: 10000, 22: 10000, 23: 10000, 24: 10000, 25: 10000, 26: 10000, 27: 10000, 28: 10000, 29: 10000, 30: 10000, 31: 20000, 32: 20000, 33: 20000, 34: 20000, 35: 20000, 36: 20000, 37: 20000, 38: 20000, 39: 20000, 40: 20000}

x_axis = []
y_axis = [ [] for _ in xrange(40) ]
y_score = []
y_clicks = []
for line in open('media_count_v2_9', 'r'):
    line = line.strip().split()
    if line :
        x_axis.append(int(line[0]))
        y_score.append((int(line[1])))
        y_clicks.append((int(line[2])))
        for y in xrange(40):
            y_axis[y].append(float(line[y+4])/max_impression[y+1])

fig, ax1 = plt.subplots(figsize=(20,10))
for i in xrange(40):
    ax1.grid(True)
    ax1.plot(x_axis, y_axis[i], '.')

ax2 = ax1.twinx()
ax2.plot(x_axis, y_score, 'r.')

ax3 = ax1.twinx()
ax3.plot(x_axis, y_clicks, 'yo')
ax3.set_title('score =  2,404,190,551 ')

#plt.hist(y_axis, 100)

# %%
# get_paid_ad2 작성. 확률 분포 변경 (turn 3)

# %matplotlib inline
import matplotlib.pyplot as plt

max_impression = {1: 2000, 2: 2000, 3: 2000, 4: 2000, 5: 2000, 6: 2000, 7: 2000, 8: 2000, 9: 2000, 10: 2000, 11: 5000, 12: 5000, 13: 5000, 14: 5000, 15: 5000, 16: 5000, 17: 5000, 18: 5000, 19: 5000, 20: 5000, 21: 10000, 22: 10000, 23: 10000, 24: 10000, 25: 10000, 26: 10000, 27: 10000, 28: 10000, 29: 10000, 30: 10000, 31: 20000, 32: 20000, 33: 20000, 34: 20000, 35: 20000, 36: 20000, 37: 20000, 38: 20000, 39: 20000, 40: 20000}

x_axis = []
y_axis = [ [] for _ in xrange(40) ]
y_score = []
y_clicks = []
for line in open('media_count_v2_10', 'r'):
    line = line.strip().split()
    if line :
        x_axis.append(int(line[0]))
        y_score.append((int(line[1])))
        y_clicks.append((int(line[2])))
        for y in xrange(40):
            y_axis[y].append(float(line[y+4])/max_impression[y+1])

fig, ax1 = plt.subplots(figsize=(20,10))
for i in xrange(40):
    ax1.grid(True)
    ax1.plot(x_axis, y_axis[i], '.')

ax2 = ax1.twinx()
ax2.plot(x_axis, y_score, 'r.')

ax3 = ax1.twinx()
ax3.plot(x_axis, y_clicks, 'yo')
ax3.set_title('score =  2,790,887,669 ')

#plt.hist(y_axis, 100)

# %%
# get_paid_ad2 작성. 확률 분포 변경 (turn 3)

# %matplotlib inline
import matplotlib.pyplot as plt

max_impression = {1: 2000, 2: 2000, 3: 2000, 4: 2000, 5: 2000, 6: 2000, 7: 2000, 8: 2000, 9: 2000, 10: 2000, 11: 5000, 12: 5000, 13: 5000, 14: 5000, 15: 5000, 16: 5000, 17: 5000, 18: 5000, 19: 5000, 20: 5000, 21: 10000, 22: 10000, 23: 10000, 24: 10000, 25: 10000, 26: 10000, 27: 10000, 28: 10000, 29: 10000, 30: 10000, 31: 20000, 32: 20000, 33: 20000, 34: 20000, 35: 20000, 36: 20000, 37: 20000, 38: 20000, 39: 20000, 40: 20000}

x_axis = []
y_axis = [ [] for _ in xrange(40) ]
y_score = []
y_clicks = []
for line in open('media_count_v2_11', 'r'):
    line = line.strip().split()
    if line :
        x_axis.append(int(line[0]))
        y_score.append((int(line[1])))
        y_clicks.append((int(line[2])))
        for y in xrange(40):
            y_axis[y].append(float(line[y+4])/max_impression[y+1])

fig, ax1 = plt.subplots(figsize=(20,10))
for i in xrange(40):
    ax1.grid(True)
    ax1.plot(x_axis, y_axis[i], '.')

ax2 = ax1.twinx()
ax2.plot(x_axis, y_score, 'r.')

ax3 = ax1.twinx()
ax3.plot(x_axis, y_clicks, 'yo')
ax3.set_title('score =   ')

#plt.hist(y_axis, 100)
